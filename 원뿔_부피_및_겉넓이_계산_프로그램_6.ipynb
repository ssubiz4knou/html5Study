# %% [markdown]
# <a href="https://colab.research.google.com/github/ssubiz4knou/html5Study/blob/main/%EC%9B%90%EB%BF%94_%EB%B6%80%ED%94%BC_%EB%B0%8F_%EA%B2%89%EB%84%93%EC%9D%B4_%EA%B3%84%EC%82%B0_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 원뿔 부피 및 겉넓이 계산 프로그램
# 반지름과 높이 사용자 입력
rad = int(input("반지름을 입력하세요: "))
hei = int(input("높이를 입력하세요: "))

if rad >= 0:
    # 모선 계산
    sla = pow(rad ** 2 + hei ** 2, 0.5)
    # 부피 & 겉넓이 출력
    vol = 1/3 * 3.14 * rad * sla
    suf = 3.14 * rad ** 2 + 3.14 * rad * sla
    print("원뿔의 부피는", str(vol) + "입니다.")
    print("원뿔의 겉넓이는", str(suf) + "입니다.")
# Out:
# 반지름을 입력하세요: 10
# 높이를 입력하세요: 24
# 원뿔의 부피는 272.1333333333333입니다.
# 원뿔의 겉넓이는 1130.4입니다.
